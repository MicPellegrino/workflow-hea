# %%
labels_surface = ['100r','110r','111r','100a','110a','111a']
labels_droplets = ['000','020','040','060','080','100']
# labels_surface = ['100r','100a']
# labels_droplets = ['000','020','100']
workdir = '/home/michele/workflow-hea/w-mo-al-ti-wetting'
lmp_run = '/home/michele/lammps-29Aug2024/build-cuda/lmp -in wetting.lammps -pk gpu 1 -sf gpu'

# %%
# !ls
# Out:
# 100a  111a		  launch-runs.ipynb  surface-test.data
# 100r  111r		  log.lammps	     system-preparation.ipynb
# 110a  combined-test.data  prepare.py	     test.lammps
# 110r  droplet-test.data   __pycache__	     test-wetting

# %%
for ls in labels_surface :
    for ld in labels_droplets:
        # %cd $workdir/$ls/$ld
        # %cp $workdir/test-wetting/*.lammps .
        # !ls
        # !$lmp_run
# %cd $workdir
# Out:
# /home/michele/workflow-hea/w-mo-al-ti-wetting/100r/000
# combined.data  wetting_AlTi_WMo.log  wetting-run.lammps
# droplet.data   wetting.dump	     wetting-settings.lammps
# log.lammps     wetting-init.lammps
# surface.data   wetting.lammps
# hwloc/linux: Ignoring PCI device with non-16bit domain.
# Pass --enable-32bits-pci-domain to configure to support such devices
# (warning: it would break the library ABI, don't enable unless really needed).
# hwloc/linux: Ignoring PCI device with non-16bit domain.
# Pass --enable-32bits-pci-domain to configure to support such devices
# (warning: it would break the library ABI, don't enable unless really needed).
# LAMMPS (29 Aug 2024 - Update 1)
# OMP_NUM_THREADS environment is not set. Defaulting to 1 thread. (src/comm.cpp:98)
#   using 1 OpenMP thread(s) per MPI task
# WARNING: Fix property/atom mol, charge, rmass, temperature, or heatflow w/out ghost communication (src/fix_property_atom.cpp:205)
# ...
